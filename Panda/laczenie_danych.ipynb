# %% [markdown]
# <a href="https://colab.research.google.com/github/DomSarr/data_science_example_1/blob/main/Panda/laczenie_danych.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def fetch_financial_data(company='AMZN'):
  import pandas_datareader.data as web
  return web.DataReader(name=company, data_source='stooq')

apple = fetch_financial_data('AAPL')
amazon = fetch_financial_data('AMZN')
google = fetch_financial_data('GOOGL')
uber = fetch_financial_data('UBER')

# %%
apple.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1257 entries, 2025-04-25 to 2020-04-27
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    1257 non-null   float64
#  1   High    1257 non-null   float64
#  2   Low     1257 non-null   float64
#  3   Close   1257 non-null   float64
#  4   Volume  1257 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 58.9 KB

# %%
apple.columns = ['apple_' + col.lower() for col in apple.columns]
amazon.columns = ['amazon_' + col.lower() for col in amazon.columns]
google.columns = ['google_' + col.lower() for col in google.columns]
uber.columns = ['uber_' + col.lower() for col in uber.columns]

# %%
onkatnechaapple.head()
# Out:
#             apple_open  apple_high  apple_low  apple_close  apple_volume
# Date
# 2025-04-25     206.365    209.7500   206.2000       209.28      38222258
# 2025-04-24     204.890    208.8299   202.9400       208.37      47310989
# 2025-04-23     206.000    208.0000   202.7990       204.60      52929165
# 2025-04-22     196.120    201.5900   195.9700       199.74      52976371
# 2025-04-21     193.265    193.8000   189.8112       193.16      46742537

# %% [markdown]
# # konkatenacja danych

# %%
import pandas as pd

# %%
df =pd.concat(objs=[apple,amazon,google,uber], axis=1)
df
# Out:
#             apple_open  apple_high  apple_low  apple_close  apple_volume  \
# Date
# 2025-04-25    206.3650    209.7500   206.2000     209.2800      38222258
# 2025-04-24    204.8900    208.8299   202.9400     208.3700      47310989
# 2025-04-23    206.0000    208.0000   202.7990     204.6000      52929165
# 2025-04-22    196.1200    201.5900   195.9700     199.7400      52976371
# 2025-04-21    193.2650    193.8000   189.8112     193.1600      46742537
# ...                ...         ...        ...          ...           ...
# 2020-05-01     69.4679     72.5585    69.3704      70.1499     247875448
# 2020-04-30     70.3697     71.4746    69.9746      71.2990     188586412
# 2020-04-29     69.0972     70.2978    68.8935      69.8247     141422205
# 2020-04-28     69.1821     69.3664    67.5147      67.6062     115383628
# 2020-04-27     68.3848     69.0521    67.9365      68.7209     120619788
#
#             amazon_open  amazon_high  amazon_low  amazon_close  amazon_volume  \
# Date
# 2025-04-25      187.620      189.940     185.490       188.990       36414330
# 2025-04-24      180.915      186.740     180.180       186.540       43763196
# 2025-04-23      183.450      187.380     180.190       180.600       63470149
# 2025-04-22      169.845      176.780     169.350       173.180       56607202
# 2025-04-21      169.600      169.600     165.285       167.320       48126111
# ...                 ...          ...         ...           ...            ...
# 2020-05-01      116.840      118.122     112.910       114.302      195452100
# 2020-04-30      120.992      123.750     119.801       123.700      190692220
# 2020-04-29      116.501      119.594     115.500       118.636       91831860
# 2020-04-28      118.605      118.675     115.300       115.704      105388920
# 2020-04-27      122.160      122.244     118.150       118.800      112912900
#
#             google_open  google_high  google_low  google_close  google_volume  \
# Date
# 2025-04-25     165.0700     166.1000    161.0400      161.9600       56033995
# 2025-04-24     156.1500     159.5900    155.7900      159.2800       45893951
# 2025-04-23     155.6100     157.5250    153.8100      155.3500       31128833
# 2025-04-22     148.8900     152.1900    148.5400      151.4700       26971774
# 2025-04-21     148.8800     148.9450    146.1000      147.6700       26049115
# ...                 ...          ...         ...           ...            ...
# 2020-05-01      65.9654      67.3274     65.2464       65.6281       49048242
# 2020-04-30      66.3276      67.2562     65.8363       67.0918       56044914
# 2020-04-29      67.0071      67.7618     66.0969       66.8667      108750567
# 2020-04-28      63.9282      64.0060     61.2968       61.4068       80992686
# 2020-04-27      64.3666      64.4713     63.0246       63.3135       44346841
#
#             uber_open  uber_high  uber_low  uber_close  uber_volume
# Date
# 2025-04-25     78.565   80.55149   77.4700       77.75     20047759
# 2025-04-24     74.155   78.38000   73.8600       78.10     22188511
# 2025-04-23     76.925   77.58000   73.2300       73.77     22750160
# 2025-04-22     73.850   75.56000   73.3500       74.44     16599288
# 2025-04-21     74.440   75.44000   71.2709       72.92     20634635
# ...               ...        ...       ...         ...          ...
# 2020-05-01     29.130   29.72000   28.3250       28.39     19290192
# 2020-04-30     30.500   31.05000   29.7500       30.27     20095396
# 2020-04-29     31.000   32.00000   30.3300       31.37     28288120
# 2020-04-28     31.000   31.83000   29.3600       30.12     27383197
# 2020-04-27     29.740   30.49000   29.4112       30.08     31705827
#
# [1257 rows x 20 columns]

# %% [markdown]
# ustawiono dwie cydry po przecinku

# %%
pd.set_option('display.float_format', lambda x:f'{x:.2f}')
df.describe().T
# Out:
#                 count        mean         std         min         25%  \
# apple_open    1257.00      161.64       39.82       68.38      133.44
# apple_high    1257.00      163.47       40.12       69.05      135.07
# apple_low     1257.00      159.96       39.59       67.51      131.84
# apple_close   1257.00      161.81       39.90       67.61      133.70
# apple_volume  1257.00 83765446.00 43889333.33 23260251.00 53392426.00
# amazon_open   1257.00      153.55       33.18       82.80      128.94
# amazon_high   1257.00      155.44       33.30       83.48      130.47
# amazon_low    1257.00      151.52       32.96       81.43      126.81
# amazon_close  1257.00      153.51       33.15       81.82      128.55
# amazon_volume 1257.00 64399003.85 30261529.95 15007497.00 43959290.00
# google_open   1257.00      125.43       32.31       63.93      100.88
# google_high   1257.00      126.88       32.56       64.01      102.08
# google_low    1257.00      124.07       32.01       61.30       99.62
# google_close  1257.00      125.49       32.27       61.41      100.77
# google_volume 1257.00 32188007.94 13436407.25  9346519.00 23442695.00
# uber_open     1257.00       47.74       16.78       20.37       33.00
# uber_high     1257.00       48.60       16.93       21.13       33.65
# uber_low      1257.00       46.86       16.56       19.89       32.28
# uber_close    1257.00       47.74       16.74       20.46       33.05
# uber_volume   1257.00 24085626.27 16542564.41  5200356.00 15669206.00
#
#                       50%         75%          max
# apple_open         158.90      185.75       257.91
# apple_high         161.26      187.32       259.81
# apple_low          157.18      183.42       257.35
# apple_close        159.19      185.75       258.74
# apple_volume  72651779.00 99942462.00 384545982.00
# amazon_open        158.13      174.60       239.01
# amazon_high        159.88      176.40       242.52
# amazon_low         156.10      172.81       238.03
# amazon_close       158.05      174.34       242.06
# amazon_volume 57559310.00 76040360.00 272661720.00
# google_open        125.79      145.36       203.39
# google_high        127.75      146.77       207.05
# google_low         124.82      143.91       202.81
# google_close       126.02      145.41       206.38
# google_volume 28939326.00 36808071.00 123645829.00
# uber_open           44.94       62.06        85.64
# uber_high           45.59       63.39        87.00
# uber_low            44.05       61.25        84.18
# uber_close          44.75       61.98        86.34
# uber_volume   20339427.00 27884447.00 364261230.00

# %% [markdown]
# korelacja

# %%
df.corr()
# Out:
#                apple_open  apple_high  apple_low  apple_close  apple_volume  \
# apple_open           1.00        1.00       1.00         1.00         -0.58
# apple_high           1.00        1.00       1.00         1.00         -0.57
# apple_low            1.00        1.00       1.00         1.00         -0.59
# apple_close          1.00        1.00       1.00         1.00         -0.58
# apple_volume        -0.58       -0.57      -0.59        -0.58          1.00
# amazon_open          0.52        0.52       0.52         0.52         -0.12
# amazon_high          0.52        0.52       0.52         0.52         -0.11
# amazon_low           0.52        0.52       0.52         0.52         -0.13
# amazon_close         0.52        0.52       0.52         0.52         -0.12
# amazon_volume       -0.52       -0.52      -0.53        -0.52          0.61
# google_open          0.89        0.89       0.89         0.89         -0.53
# google_high          0.89        0.89       0.89         0.89         -0.53
# google_low           0.89        0.89       0.89         0.89         -0.54
# google_close         0.89        0.89       0.89         0.89         -0.53
# google_volume       -0.19       -0.18      -0.20        -0.19          0.35
# uber_open            0.65        0.65       0.65         0.65         -0.37
# uber_high            0.65        0.65       0.65         0.65         -0.37
# uber_low             0.65        0.65       0.66         0.65         -0.38
# uber_close           0.65        0.65       0.65         0.65         -0.37
# uber_volume         -0.05       -0.05      -0.05        -0.05          0.13
#
#                amazon_open  amazon_high  amazon_low  amazon_close  \
# apple_open            0.52         0.52        0.52          0.52
# apple_high            0.52         0.52        0.52          0.52
# apple_low             0.52         0.52        0.52          0.52
# apple_close           0.52         0.52        0.52          0.52
# apple_volume         -0.12        -0.11       -0.13         -0.12
# amazon_open           1.00         1.00        1.00          1.00
# amazon_high           1.00         1.00        1.00          1.00
# amazon_low            1.00         1.00        1.00          1.00
# amazon_close          1.00         1.00        1.00          1.00
# amazon_volume        -0.31        -0.30       -0.32         -0.31
# google_open           0.70         0.70        0.70          0.70
# google_high           0.70         0.70        0.70          0.70
# google_low            0.70         0.70        0.70          0.70
# google_close          0.70         0.70        0.70          0.70
# google_volume        -0.18        -0.17       -0.19         -0.18
# uber_open             0.77         0.76        0.77          0.77
# uber_high             0.77         0.76        0.77          0.77
# uber_low              0.76         0.76        0.77          0.76
# uber_close            0.76         0.76        0.77          0.77
# uber_volume          -0.09        -0.09       -0.10         -0.10
#
#                amazon_volume  google_open  google_high  google_low  \
# apple_open             -0.52         0.89         0.89        0.89
# apple_high             -0.52         0.89         0.89        0.89
# apple_low              -0.53         0.89         0.89        0.89
# apple_close            -0.52         0.89         0.89        0.89
# apple_volume            0.61        -0.53        -0.53       -0.54
# amazon_open            -0.31         0.70         0.70        0.70
# amazon_high            -0.30         0.70         0.70        0.70
# amazon_low             -0.32         0.70         0.70        0.70
# amazon_close           -0.31         0.70         0.70        0.70
# amazon_volume           1.00        -0.52        -0.51       -0.53
# google_open            -0.52         1.00         1.00        1.00
# google_high            -0.51         1.00         1.00        1.00
# google_low             -0.53         1.00         1.00        1.00
# google_close           -0.52         1.00         1.00        1.00
# google_volume           0.50        -0.22        -0.21       -0.24
# uber_open              -0.47         0.71         0.71        0.71
# uber_high              -0.47         0.71         0.71        0.71
# uber_low               -0.48         0.71         0.71        0.72
# uber_close             -0.47         0.71         0.71        0.71
# uber_volume             0.21        -0.05        -0.05       -0.06
#
#                google_close  google_volume  uber_open  uber_high  uber_low  \
# apple_open             0.89          -0.19       0.65       0.65      0.65
# apple_high             0.89          -0.18       0.65       0.65      0.65
# apple_low              0.89          -0.20       0.65       0.65      0.66
# apple_close            0.89          -0.19       0.65       0.65      0.65
# apple_volume          -0.53           0.35      -0.37      -0.37     -0.38
# amazon_open            0.70          -0.18       0.77       0.77      0.76
# amazon_high            0.70          -0.17       0.76       0.76      0.76
# amazon_low             0.70          -0.19       0.77       0.77      0.77
# amazon_close           0.70          -0.18       0.77       0.77      0.76
# amazon_volume         -0.52           0.50      -0.47      -0.47     -0.48
# google_open            1.00          -0.22       0.71       0.71      0.71
# google_high            1.00          -0.21       0.71       0.71      0.71
# google_low             1.00          -0.24       0.71       0.71      0.72
# google_close           1.00          -0.23       0.71       0.71      0.71
# google_volume         -0.23           1.00      -0.19      -0.19     -0.20
# uber_open              0.71          -0.19       1.00       1.00      1.00
# uber_high              0.71          -0.19       1.00       1.00      1.00
# uber_low               0.71          -0.20       1.00       1.00      1.00
# uber_close             0.71          -0.20       1.00       1.00      1.00
# uber_volume           -0.05           0.21      -0.17      -0.16     -0.18
#
#                uber_close  uber_volume
# apple_open           0.65        -0.05
# apple_high           0.65        -0.05
# apple_low            0.65        -0.05
# apple_close          0.65        -0.05
# apple_volume        -0.37         0.13
# amazon_open          0.76        -0.09
# amazon_high          0.76        -0.09
# amazon_low           0.77        -0.10
# amazon_close         0.77        -0.10
# amazon_volume       -0.47         0.21
# google_open          0.71        -0.05
# google_high          0.71        -0.05
# google_low           0.71        -0.06
# google_close         0.71        -0.05
# google_volume       -0.20         0.21
# uber_open            1.00        -0.17
# uber_high            1.00        -0.16
# uber_low             1.00        -0.18
# uber_close           1.00        -0.17
# uber_volume         -0.17         1.00

# %%
closes = [col for col in df.columns if col.endswith('close')]
closes
# Out:
# ['apple_close', 'amazon_close', 'google_close', 'uber_close']

# %% [markdown]
# korelacja dla cen zamykajacych

# %%
df[closes].corr()
# Out:
#               apple_close  amazon_close  google_close  uber_close
# apple_close          1.00          0.52          0.89        0.65
# amazon_close         0.52          1.00          0.70        0.77
# google_close         0.89          0.70          1.00        0.71
# uber_close           0.65          0.77          0.71        1.00

# %% [markdown]
# # Metoda append()

# %%
uber.head()
# Out:
#             uber_open  uber_high  uber_low  uber_close  uber_volume
# Date
# 2025-04-25      78.56      80.55     77.47       77.75     20047759
# 2025-04-24      74.16      78.38     73.86       78.10     22188511
# 2025-04-23      76.92      77.58     73.23       73.77     22750160
# 2025-04-22      73.85      75.56     73.35       74.44     16599288
# 2025-04-21      74.44      75.44     71.27       72.92     20634635

# %%
uber_6 = uber[uber.index.month ==6]
uber_6
# Out:
#             uber_open  uber_high  uber_low  uber_close  uber_volume
# Date
# 2024-06-28      70.81      73.26     70.77       72.68     21375880
# 2024-06-27      70.98      71.32     70.07       70.34      9650481
# 2024-06-26      70.94      71.60     70.55       70.85     10232568
# 2024-06-25      71.86      72.94     70.22       71.38     18911562
# 2024-06-24      69.83      71.23     69.75       70.54     12479277
# ...               ...        ...       ...         ...          ...
# 2020-06-05      37.53      38.78     36.92       37.21     30393429
# 2020-06-04      36.42      37.30     36.28       36.43     17423577
# 2020-06-03      36.20      37.37     36.14       36.75     23051776
# 2020-06-02      36.16      36.42     35.26       35.81     19328415
# 2020-06-01      35.64      36.39     35.16       35.82     21893806
#
# [105 rows x 5 columns]

# %%
uber_7 = uber[uber.index.month ==7]
uber_7
# Out:
#             uber_open  uber_high  uber_low  uber_close  uber_volume
# Date
# 2024-07-31      63.88      65.18     63.66       64.47     18209679
# 2024-07-30      64.15      64.77     62.61       63.09     16506187
# 2024-07-29      64.83      65.26     63.72       63.76     16906996
# 2024-07-26      66.10      66.26     64.18       64.40     17379446
# 2024-07-25      66.00      69.37     64.40       65.74     22596919
# ...               ...        ...       ...         ...          ...
# 2020-07-08      33.21      33.97     32.68       33.93     24602369
# 2020-07-07      32.46      33.56     32.39       32.82     34874658
# 2020-07-06      33.10      33.20     31.76       32.52     42392222
# 2020-07-02      31.02      31.57     30.51       30.68     14981137
# 2020-07-01      30.96      31.27     30.16       30.43     13611544
#
# [105 rows x 5 columns]

# %%
import pandas as pd

# %%
uber_6.append(uber_7)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-40-69cd6d4bc6d1> in <cell line: 0>()
# ----> 1 uber_6.append(uber_7)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'DataFrame' object has no attribute 'append'
